# %% [markdown]
# Given a string s, find the length of the longest substring without repeating characters.
#
#
#
# Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
# Example 4:
#
# Input: s = ""
# Output: 0
#
#
# Constraints:
#
# 0 <= s.length <= 5 * 104
# s consists of English letters, digits, symbols and spaces.

# %% [markdown]
# Here is the template solution to start

# %%
#format of solution
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:

# %% [markdown]
# Here we set a string to play with

# %%
string1 = "pwwkew"

# %% [markdown]
# We experiement with what .find does

# %%
string1.find('p') #finds index where 'p' is located
# Out:
# 0

# %%
string1.find('z')
# Out:
# -1

# %%
string1.split('w') #splits string where 'w' is located
# Out:
# ['p', '', 'ke', '']

# %%
for i, char in enumerate(string1):
    print(i, char)
# Out:
# 0 p
# 1 w
# 2 w
# 3 k
# 4 e
# 5 w

# %%
string1 = "dvdf"
sub_str1 = sub_str2 = "" #initiate an empty string
end_substring1 = start_substring2 = 0
sub_string_list = []

for i, char in enumerate(string1): #iterate through the string
    if (sub_str1.find(char)==-1) and (start_substring2>=i):
        sub_str1 = sub_str1 + char
        end_substring1 = i
        start_substring2 = i + 1
        print('substring1:',sub_str1, end_substring1, '\n')
    elif (sub_str2.find(char) ==-1):
        sub_str2 = sub_str2 + char
        print('substring2:', sub_str2, i, '\n')
    else:
        print(sub_str1, sub_str2, i)
        sub_string_list.append(sub_str1)
        sub_string_list.append(sub_str2)
        sub_str1 = max(sub_string_list, key=len)
        sub_str2 = char
        sub_string_list = []
    sub_str1 = max([sub_str1, sub_str2], key=len)
print(sub_str1)
# Out:
# substring1: d 0
#
# substring1: dv 1
#
# substring2: d 2
#
# substring2: df 3
#
# dv

# %%
#Here is our test string
string1 = "dvdf"
string1[1:]
# Out:
# 'vdf'

# %% [markdown]
# Still working on personal solution:

# %%
string1 = "yzcrkylidvgqxebwmubplzxihjlvataasdsfdfngavyyabuowyfhzcpglcdoxeoqjivmnkuofsohti"
sub_string_list = []
for j in range(len(string1)):
    sub_str1 = sub_str2 = "" #initiate an empty string
    end_substring1 = start_substring2 = 0

    for i, char in enumerate(string1[j:]): #iterate through the string
        if (sub_str1.find(char)==-1) and (start_substring2>=i):
            sub_str1 = sub_str1 + char
            end_substring1 = i
            start_substring2 = i + 1
            print('1. substring1:',sub_str1, end_substring1, '\n')
        elif (sub_str2.find(char) ==-1):
            sub_str2 = sub_str2 + char
            print('2. substring2:', sub_str2, i, '\n')
        else:
            print('3.',sub_str1, sub_str2, i)
            sub_str1 = max([sub_str1,sub_str2], key=len)
            sub_str2 = char
    sub_string_list.append(sub_str1)
    sub_string_list.append(sub_str2)
    print('5.', sub_string_list)
print('6.', len(max(sub_string_list, key=len)))
# Out:
# 1. substring1: y 0
#
# 1. substring1: yz 1
#
# 1. substring1: yzc 2
#
# 1. substring1: yzcr 3
#
# 1. substring1: yzcrk 4
#
# 2. substring2: y 5
#
# 2. substring2: yl 6
#
# 2. substring2: yli 7
#
# 2. substring2: ylid 8
#
# 2. substring2: ylidv 9
#
# 2. substring2: ylidvg 10
#
# 2. substring2: ylidvgq 11
#
# 2. substring2: ylidvgqx 12
#
# 2. substring2: ylidvgqxe 13
#
# 2. substring2: ylidvgqxeb 14
#
# 2. substring2: ylidvgqxebw 15
#
# 2. substring2: ylidvgqxebwm 16
#
# 2. substring2: ylidvgqxebwmu 17
#
# 3. yzcrk ylidvgqxebwmu 18
# 2. substring2: bp 19
#
# 2. substring2: bpl 20
#
# 2. substring2: bplz 21
#
# 2. substring2: bplzx 22
#
# 2. substring2: bplzxi 23
#
# 2. substring2: bplzxih 24
#
# 2. substring2: bplzxihj 25
#
# 3. ylidvgqxebwmu bplzxihj 26
# 2. substring2: lv 27
#
# 2. substring2: lva 28
#
# 2. substring2: lvat 29
#
# 3. ylidvgqxebwmu lvat 30
# 3. ylidvgqxebwmu a 31
# 2. substring2: as 32
#
# 2. substring2: asd 33
#
# 3. ylidvgqxebwmu asd 34
# 2. substring2: sf 35
#
# ...

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        string1 = s #initiate with string
        sub_string_list = [] #initiate empty list
        for j in range(len(string1)):
            sub_str1 = sub_str2 = "" #initiate an empty string
            end_substring1 = start_substring2 = 0

            for i, char in enumerate(string1[j:]): #iterate through the string
                if (sub_str1.find(char)==-1) and (start_substring2>=i):
                    sub_str1 = sub_str1 + char
                    end_substring1 = i
                    start_substring2 = i + 1
                    print('1. substring1:',sub_str1, end_substring1, '\n')
                elif (sub_str2.find(char) ==-1):
                    sub_str2 = sub_str2 + char
                    print('2. substring2:', sub_str2, i, '\n')
                else:
                    print('3.',sub_str1, sub_str2, i)
                    sub_str1 = max([sub_str1,sub_str2], key=len)
                    sub_str2 = char
            sub_string_list.append(sub_str1)
            sub_string_list.append(sub_str2)
        return len(max(sub_string_list, key=len))

# %% [markdown]
# Better solution below:

# %%
#Here is the solution I want to get to 
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        used = {} #initiate empty dict
        max_length = start = 0 #Initiate variable
        for i, c in enumerate(s): #iterate through string index and object
            if c in used and start <= used[c]:
                start = used[c] + 1 #move to next one
            else:
                max_length = max(max_length, i - start + 1)

            used[c] = i


        return max_length #This returns the one with the longest sequence
